# %%
# ADD BIN HERE

import os
import sys
import pandas as pd
import random
import matplotlib.pyplot as plt
import sqlite3
from bs4 import BeautifulSoup, ResultSet
import urllib.request
import re
import glob
import warnings
from tqdm import tnrange, tqdm_notebook

warnings.filterwarnings('ignore')
random.seed(666)

# %%
# Connect to SQL Database and reads every Table in the whole DB
# Then converts each table into a .csv file so we can work with themn in Python

def to_csv():

    os.chdir("/home/chris/HOPE/") # HARDCODED 
    db = sqlite3.connect('read.db')
    os.chdir("/home/chris/HOPE/old_db") # HARDCODED 
    cursor = db.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    for table_name in tqdm_notebook(tables):
        table_name = table_name[0]
        table = pd.read_sql_query("SELECT * from %s" % table_name, db)
        table.to_csv(table_name + '.csv', index_label='index')
    cursor.close()
    db.close()

to_csv()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=19.0), HTML(value='')))

# %%
# Print the names of the 17 individual .db tables you just built

files = pd.DataFrame([])
for fname in glob.glob("/home/chris/HOPE/old_db/*.csv"): # HARDCODED 
    fname = fname.rsplit("/", 1)
    fname = pd.DataFrame(pd.Series(fname[1]))
    files = files.append(fname)
print(files)


# Load the data 
AuthorAlias =      pd.read_csv("AuthorAlias.csv")
JEL =              pd.read_csv("JEL.csv")
Children =         pd.read_csv("Children.csv")
Nber =             pd.read_csv("Nber.csv")
NBERCorr =         pd.read_csv("NBERCorr.csv")
NBERStat =         pd.read_csv("NBERStat.csv")
sqlite_sequence =  pd.read_csv("sqlite_sequence.csv")
Inst =             pd.read_csv("Inst.csv")
sqlite_stat4 =     pd.read_csv("sqlite_stat4.csv")
InstCorr =         pd.read_csv("InstCorr.csv")
InstAlias =        pd.read_csv("InstAlias.csv")
JournalName =      pd.read_csv("JournalName.csv")
Article =          pd.read_csv("Article.csv")
ReadStat =         pd.read_csv("ReadStat.csv")
sqlite_stat1 =     pd.read_csv("sqlite_stat1.csv")
AuthorCorr =       pd.read_csv("AuthorCorr.csv")
DOICorr =          pd.read_csv("DOICorr.csv")
Author =           pd.read_csv("Author.csv")
EditorBoard =      pd.read_csv("EditorBoard.csv")
# Out:
#                      0
# 0      AuthorAlias.csv
# 0              JEL.csv
# 0         Children.csv
# 0             Nber.csv
# 0         NBERCorr.csv
# 0         NBERStat.csv
# 0  sqlite_sequence.csv
# 0             Inst.csv
# 0     sqlite_stat4.csv
# 0         InstCorr.csv
# 0        InstAlias.csv
# 0      JournalName.csv
# 0          Article.csv
# 0         ReadStat.csv
# 0     sqlite_stat1.csv
# 0       AuthorCorr.csv
# 0          DOICorr.csv
# 0           Author.csv
# 0      EditorBoard.csv

# %%
def find_latest(journal):
    
    """
    This function finds the "newest" metadata and saves it as variables that we use later on
    We then use these variables later on to automate thresholds and cutoffs
    This is done bcause we specficially do NOT WANT to grab any data prior to our cutoff
    """
    
    data = Article[Article["Journal"] == journal]
    data = data.sort_values(by=["Volume", "Issue"])
    data = pd.DataFrame(data.iloc[-1,:])
    data = data.T
    volume = int(data["Volume"])
    issue = int(data["Issue"])

    return(volume, issue)

latest_eca_volume, latest_eca_issue = find_latest("ECA")
latest_aer_volume, latest_aer_issue = find_latest("AER")
latest_jpe_volume, latest_jpe_issue = find_latest("JPE")
latest_qje_volume, latest_qje_issue = find_latest("QJE")
latest_res_volume, latest_res_issue = find_latest("RES")

# %%
def scrape_repec(journal_name, root_url, pages, latest_volume, latest_issue):

    """
    This is a webcrawler that crawls through every page/article of a
    TO DO: Make the webcrawler  "smarter" so that it can detect that there are 17 pages of data to scrape
    TO DO: Scrape more than 5 journals
    """

    # Soupa nd link 
    links = pd.DataFrame([])
    for i in tqdm_notebook(range(1, pages)):
        url = root_url       
        if i > 1:  # "1" workaround is due to their uniue naming convenitons
            url = url[:-5] + str(i) + url[-5:]
        html_page = urllib.request.urlopen(url)
        soup = BeautifulSoup(html_page, "html.parser")
        for link in soup.find_all('a', href=True): # Grab all the URL hyperlinks on the webpage
            links = links.append(pd.DataFrame(pd.Series(link['href']))) 
    links.columns = ["url"]
    links = links[links['url'].str.contains("/a/")]
    links = "https://ideas.repec.org" + links
    links["metadata"] = links["url"]

    # Metadata manipulation; haervests volume, issue, year, and pages of the scrape d ata
    # TECHNICAL DEBT! These 6 lines are ugly and gross
    links["metadata"] = links["metadata"].str.split("v", n=1, expand=True)[1]
    links["Volume"] = links["metadata"].str.split("y", n=1, expand=True)[0]
    links["metadata"] = links["metadata"].str.split("y", n=1, expand=True)[1]
    links["y"] = links["metadata"].str.split("i", n=1, expand=True)[0]
    links["metadata"] = links["metadata"].str.split("i", n=1, expand=True)[1]
    links["Issue"] = links["metadata"].str.split("p", n=1, expand=True)[0]
    links["metadata"] = links["metadata"].str.split("p", n=1, expand=True)[1]
    links["FirstPage"] = links["metadata"].str.split("-", n=1, expand=True)[0]
    links["metadata"] = links["metadata"].str.split("-", n=1, expand=True)[1]
    links["LastPage"] = links["metadata"].str.split(".", n=1, expand=True)[0]
    links = links.drop(columns = ["metadata"])
    links["Volume"] = pd.to_numeric(links["Volume"])
    links = links[links["Volume"] > latest_volume] # CUTOFF FOR NEWEST ONLY 
    
    # Now we loop through all the individual URLs to scrape some more specific metadata
    # Question: Do citations from the original data soruce hold up?
    data = pd.DataFrame([]) # intialize empty dfs to be filled up in loop
    author = pd.DataFrame([])
    for url in tqdm_notebook(links["url"]):
        df = links[links["url"] == url]
        html_page = urllib.request.urlopen(url)
        soup = BeautifulSoup(html_page, "html.parser")
        
        # Author(s)        
        author = str(soup.find(id ="title"))
        author = str(author[21:-11]) # HARDCODED 
        df["Title"] = title
        
        # Title
        title = str(soup.find(id ="title"))
        title = str(title[21:-11]) # HARDCODED 
        df["Title"] = title

        # Abstract        
        abstract = str(soup.find(id ="abstract-body"))
        abstract = str(abstract[24:-6]) # HARDCODED 
        df["Abstract"] = abstract

        # Citations
        citations = str(soup.find(id ="cites-tab"))
        if len(citations) == 4:
            df["CiteCount"] = 0
        else:
            citations = str(citations.split("role")[1])
            citations = str(citations.split("Citations")[0])
            citations = str(citations.split(">")[1])
            df["CiteCount"] = citations
        
        # Create empty columns (quick/dirty workaround) that formats table such that you can append it to SQL 
        df["Journal"] = journal_name
        df["index"] = "MISSING"
        df["ArticleID"] = "MISSING"
        df["Language"] = "MISSING"
        df["Received"] = "MISSING"
        df["Accepted"] = "MISSING"
        df["Part"] = "MISSING"
        df["Comments"] = "MISSING"
        df["Note"] = "MISSING"
        df["PubDate"] = "MISSING"
        df = df.drop(columns = ["y", "url"]) #  Technical debt 
        data = data.append(df) 
    data = data[Article.columns] # HARDCODED 

    return(data)

# TOMROROW: FInish all 17 tables

# %%
#                     0
#0      AuthorAlias.csv
#0              JEL.csv
#0         Children.csv
#0             Nber.csv
#0         NBERCorr.csv
#0         NBERStat.csv
#0  sqlite_sequence.csv
#0             Inst.csv
#0     sqlite_stat4.csv
#0         InstCorr.csv
#0        InstAlias.csv
#0      JournalName.csv
#0          Article.csv
#0         ReadStat.csv
#0     sqlite_stat1.csv
#0       AuthorCorr.csv
#0          DOICorr.csv
#0           Author.csv
#0      EditorBoard.csv
AuthorCorr
# Out:
#        index  AuthorID  ArticleID  AuthorOrder
# 0          0       191       2795            0
# 1          1       489       2796            0
# 2          2      3953       2796            0
# 3          3      1232       2797            0
# 4          4       162       2797            0
# ...      ...       ...        ...          ...
# 20841  20841      5127      11721            0
# 20842  20842      2470      11722            0
# 20843  20843      9619      11722            0
# 20844  20844      9453      11723            0
# 20845  20845       549      11724            0
#
# [20846 rows x 4 columns]

# %%
qje = scrape_repec(journal_name = "QJE", root_url = "https://ideas.repec.org/s/oup/qjecon.html", pages = 2, latest_volume = latest_qje_volume, latest_issue = latest_qje_issue)

# %%
qje = scrape_repec(journal_name = "QJE", root_url = "https://ideas.repec.org/s/oup/qjecon.html", pages = 2, latest_volume = latest_qje_volume, latest_issue = latest_qje_issue) 
aer = scrape_article_urls(root_url = "https://ideas.repec.org/s/ecm/emetrp.html", pages = 17, latest_volume = latest_aer_volume, latest_issue = latest_aer_issue)
jpe = scrape_article_urls(root_url = "https://ideas.repec.org/s/ecm/emetrp.html", pages = 17, latest_volume = latest_jpe_volume, latest_issue = latest_jpe_volume)
eca = scrape_article_urls(root_url = "https://ideas.repec.org/s/ecm/emetrp.html", pages = 17, latest_volume = 2, latest_issue = 2)
res = scrape_article_urls(root_url = "https://ideas.repec.org/s/ecm/emetrp.html", pages = 17, latest_volume = 2, latest_issue = 2)
# Out:
#       index ArticleID Journal  PubDate  \
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# ..      ...       ...     ...      ...
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
#
#                                                 Title  \
# 0                         The Return to Protectionism
# 0   Cash and the Economy: Evidence from Indiaâ€™s ...
# 0   Productivity and Misallocation in General Equi...
# 0   Inflation Expectations and Firm Decisions: New...
# 0   How Acquisitions Affect Firm Behavior and Perf...
# ..                                                ...
# 0   Ghost-House Busters: The Electoral Response to...
# 0   Dynamic Selection: An Idea Flows Theory of Ent...
# 0   Political Centralization and Government Accoun...
# 0   The Effects of Youth Employment: Evidence from...
# 0      Efficiency, Welfare, and Political Competition
#
#                                              Abstract Language Received  \
# 0   After decades of supporting free trade, in 201...  MISSING  MISSING
# 0   We analyze a unique episode in the history of ...  MISSING  MISSING
# 0   This paper develops a general theory of aggreg...  MISSING  MISSING
# 0   We use a unique design feature of a survey of ...  MISSING  MISSING
# 0   Many industries have become increasingly conce...  MISSING  MISSING
# ..                                                ...      ...      ...
# 0   The incentives of political agents to enforce ...  MISSING  MISSING
# 0   This article develops an idea flows theory of ...  MISSING  MISSING
# 0   This article explains why decentralization can...  MISSING  MISSING
# 0   Programs to encourage labor market activity am...  MISSING  MISSING
# 0   We study political competition in an environme...  MISSING  MISSING
#
#    Accepted  Volume Issue     Part FirstPage LastPage Comments CiteCount  \
# 0   MISSING     135     1  MISSING         1       55  MISSING       15
# 0   MISSING     135     1  MISSING        57      103  MISSING         0
# 0   MISSING     135     1  MISSING       105      163  MISSING       22
# 0   MISSING     135     1  MISSING       165      219  MISSING        8
# 0   MISSING     135     1  MISSING       221      267  MISSING         0
# ..      ...     ...   ...      ...       ...      ...      ...       ...
# 0   MISSING     131     1  MISSING       273      314  MISSING       30
# 0   MISSING     131     1  MISSING       315      380  MISSING       33
# 0   MISSING     131     1  MISSING       381      422  MISSING       15
# 0   MISSING     131     1  MISSING       423      460  MISSING        9
# 0   MISSING     131     1  MISSING       461      518  MISSING       14
#
#        Note
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
# ..      ...
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
#
# [173 rows x 17 columns]

# %%
qje
# Out:
#       index ArticleID Journal  PubDate  \
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# ..      ...       ...     ...      ...
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
# 0   MISSING   MISSING     QJE  MISSING
#
#                                                 Title  \
# 0                         The Return to Protectionism
# 0   Cash and the Economy: Evidence from Indiaâ€™s ...
# 0   Productivity and Misallocation in General Equi...
# 0   Inflation Expectations and Firm Decisions: New...
# 0   How Acquisitions Affect Firm Behavior and Perf...
# ..                                                ...
# 0   Ghost-House Busters: The Electoral Response to...
# 0   Dynamic Selection: An Idea Flows Theory of Ent...
# 0   Political Centralization and Government Accoun...
# 0   The Effects of Youth Employment: Evidence from...
# 0      Efficiency, Welfare, and Political Competition
#
#                                              Abstract Language Received  \
# 0   After decades of supporting free trade, in 201...  MISSING  MISSING
# 0   We analyze a unique episode in the history of ...  MISSING  MISSING
# 0   This paper develops a general theory of aggreg...  MISSING  MISSING
# 0   We use a unique design feature of a survey of ...  MISSING  MISSING
# 0   Many industries have become increasingly conce...  MISSING  MISSING
# ..                                                ...      ...      ...
# 0   The incentives of political agents to enforce ...  MISSING  MISSING
# 0   This article develops an idea flows theory of ...  MISSING  MISSING
# 0   This article explains why decentralization can...  MISSING  MISSING
# 0   Programs to encourage labor market activity am...  MISSING  MISSING
# 0   We study political competition in an environme...  MISSING  MISSING
#
#    Accepted  Volume Issue     Part FirstPage LastPage Comments CiteCount  \
# 0   MISSING     135     1  MISSING         1       55  MISSING       15
# 0   MISSING     135     1  MISSING        57      103  MISSING         0
# 0   MISSING     135     1  MISSING       105      163  MISSING       22
# 0   MISSING     135     1  MISSING       165      219  MISSING        8
# 0   MISSING     135     1  MISSING       221      267  MISSING         0
# ..      ...     ...   ...      ...       ...      ...      ...       ...
# 0   MISSING     131     1  MISSING       273      314  MISSING       30
# 0   MISSING     131     1  MISSING       315      380  MISSING       33
# 0   MISSING     131     1  MISSING       381      422  MISSING       15
# 0   MISSING     131     1  MISSING       423      460  MISSING        9
# 0   MISSING     131     1  MISSING       461      518  MISSING       14
#
#        Note
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
# ..      ...
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
# 0   MISSING
#
# [173 rows x 17 columns]

# %%
print(len(Article.columns))
# Out:
# 17

# %%
# Out:
#                                                   url  Volume     y Issue  \
# 0   https://ideas.repec.org/a/oup/qjecon/v135y2020...     135  2020     1
# 0   https://ideas.repec.org/a/oup/qjecon/v135y2020...     135  2020     1
# 0   https://ideas.repec.org/a/oup/qjecon/v135y2020...     135  2020     1
# 0   https://ideas.repec.org/a/oup/qjecon/v135y2020...     135  2020     1
# 0   https://ideas.repec.org/a/oup/qjecon/v135y2020...     135  2020     1
# ..                                                ...     ...   ...   ...
# 0   https://ideas.repec.org/a/oup/qjecon/v131y2016...     131  2016     1
# 0   https://ideas.repec.org/a/oup/qjecon/v131y2016...     131  2016     1
# 0   https://ideas.repec.org/a/oup/qjecon/v131y2016...     131  2016     1
# 0   https://ideas.repec.org/a/oup/qjecon/v131y2016...     131  2016     1
# 0   https://ideas.repec.org/a/oup/qjecon/v131y2016...     131  2016     1
#
#    start_page end_page CiteCount
# 0           1       55       15
# 0          57      103         0
# 0         105      163       22
# 0         165      219        8
# 0         221      267         0
# ..        ...      ...       ...
# 0         273      314       30
# 0         315      380       33
# 0         381      422       15
# 0         423      460        9
# 0         461      518       14
#
# [173 rows x 7 columns]

# %%
html_page = urllib.request.urlopen(url)
soup = BeautifulSoup(html_page, "html.parser")
citations = str(soup.find(id ="cites-tab"))
citations = str(citations.split("role=\"tab\">")[1])
citations = int(citations.split("Citations")[0])

# %%
for url in qje["url"]:
    print(url)
# Out:
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p1-55..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p57-103..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p105-163..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p165-219..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p221-267..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p269-327..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p329-388..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p389-448..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p449-502..html
# https://ideas.repec.org/a/oup/qjecon/v135y2020i1p503-560..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p1675-1745..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p1747-1791..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p1793-1844..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p1845-1882..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p1883-1948..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p1949-2010..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p2011-2084..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p2085-2134..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p2135-2202..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i4p2203-2236..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1121-1162..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1163-1224..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1225-1298..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1299-1342..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1343-1404..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1405-1454..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1455-1503..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1505-1556..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1557-1626..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i3p1627-1673..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p557-598..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p599-646..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p647-713..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p715-783..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p785-842..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p843-894..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p895-951..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p953-1019..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p1021-1077..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i2p1079-1120..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p1-50..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p51-107..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p109-183..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p185-226..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p227-279..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p281-347..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p349-396..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p397-450..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p451-505..html
# https://ideas.repec.org/a/oup/qjecon/v134y2019i1p507-556..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1645-1692..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1693-1751..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1753-1801..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1803-1884..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1885-1932..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1933-1980..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p1981-2036..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p2037-2096..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p2097-2169..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i4p2171-2214..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1107-1162..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1163-1228..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1229-1282..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1283-1330..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1331-1393..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1395-1458..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1459-1501..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1503-1560..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1561-1595..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i3p1597-1644..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p553-609..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p611-663..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p665-700..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p701-764..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p765-800..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p801-870..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p871-925..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p927-991..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p993-1039..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i2p1041-1105..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p1-70..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p71-127..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p129-190..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p191-235..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p237-293..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p295-355..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p357-406..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p407-455..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p457-507..html
# https://ideas.repec.org/a/oup/qjecon/v133y2018i1p509-551..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1553-1592..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1593-1640..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1641-1692..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1693-1754..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1755-1817..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1819-1876..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1877-1914..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1915-1967..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p1969-2018..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p2019-2055..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p2057-2060..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i4p2061-2062..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1055-1100..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1101-1164..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1165-1217..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1219-1260..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1261-1318..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1319-1372..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1373-1426..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1427-1467..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1469-1508..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1509-1550..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i3p1551-1552..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p551-615..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p617-663..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p665-712..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p713-764..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p765-809..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p811-870..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p871-919..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p921-962..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p963-1018..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i2p1019-1054..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p1-54..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p55-102..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p103-155..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p157-209..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p211-270..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p271-316..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p317-365..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p367-433..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p435-483..html
# https://ideas.repec.org/a/oup/qjecon/v132y2017i1p485-549..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1593-1636..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1637-1680..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1681-1726..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1727-1752..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1753-1794..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1795-1848..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1849-1874..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1875-1926..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1927-1971..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i4p1973-2042..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1057-1111..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1113-1180..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1181-1242..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1243-1290..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1291-1364..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1365-1413..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1415-1453..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1455-1495..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1497-1542..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i3p1543-1592..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p519-578..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p579-631..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p633-686..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p687-738..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p739-798..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p799-858..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p859-890..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p891-941..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p943-1005..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i2p1007-1056..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p1-52..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p53-87..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p89-155..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p157-218..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p219-271..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p273-314..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p315-380..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p381-422..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p423-460..html
# https://ideas.repec.org/a/oup/qjecon/v131y2016i1p461-518..html

# %%
citations
# Out:
# 14

# %%
# JEL Codes per Journal - how have they evolved over time?
# Technichal debt - can be made much sleeker
set(JournalName.Journal)
ECA_articles = set(Article[Article["Journal"] == "ECA"].iloc[:,1])
AER_articles = set(Article[Article["Journal"] == "AER"].iloc[:,1])
JPE_articles = set(Article[Article["Journal"] == "JPE"].iloc[:,1])
RES_articles = set(Article[Article["Journal"] == "RES"].iloc[:,1])
QJE_articles = set(Article[Article["Journal"] == "QJE"].iloc[:,1])
top5_articles = [ECA_articles, AER_articles, JPE_articles, RES_articles, QJE_articles]

# Make flags for every JEL code via loop
# I figure we might need these flags for fixed effects or something at some point
df = Article # I just like working with df better
articles = set(Article.ArticleID)
JEL_codes =
for article in tqdm(articles):

# Now split this graph into two
    chunk = JEL[JEL["ArticleID"] == article]
    moving average of JEL codes per year per journal

    print(df)
    print(article)

# That's a picture for the entier thign, yes but how have they evolved over time?
# 1 Pie Chart Per Decade Per Journal of JEL Codes
# Investigate articles with zero JEL codes. Is that something I have to go get?

JEL
JEL_tally = JEL.groupby("JEL").count()
JEL_tally = JEL_tally.iloc[:,1]
print( JEL_tally )

# The growth of the averga page length over time
# Difference in page length between men and women

## Exploratory regressions

## Write SQL code that connects to db

## Appends lines as new data

## Closes connection
# Descriptive Statistics


# Break it down by Author Order

#
# Productiviy per Age -  broken down by Gender
    # Metric 1: Average number of citations/publications for each age



# Quantifying Dynamics of Gendered Network Formation
# Gendered Network Formation in Top 5 Economics Journals
# First turn everything into nodes and edges

nodes = JEL
https://programminghistorian.org/en/lessons/exploring-and-analyzing-network-data-with-python








for row in c.execute('SELECT * WHERE type=\'table\';'):
    print(row)
.execute("SELECT name FROM my_db.db ;")

conn.close()


ATTACH some_file.db AS my_db;

then you need to do

S

clsoe





c = conn.cursor()

# Create table
#c.execute('''CREATE TABLE stocks
#             (date text, trans text, symbol text, qty real, price real)''')

# Insert a row of data
# c.execute("INSERT INTO stocks VALUES ('2006-01-05','BUY','RHAT',100,35.14)")

# Save (commit) the changes
#conn.commit()

# We can also close the connection if we are done with it.
# Just be sure any changes have been committed or they will be lost.
conn.close()

# %%
# Reindx 

# New Journal IDs
